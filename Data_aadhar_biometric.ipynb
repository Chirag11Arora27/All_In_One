# %% [markdown]
# <a href="https://colab.research.google.com/github/Chirag11Arora27/All_In_One/blob/main/Data_aadhar_biometric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
state_bio = (
      df.groupby('state')['total_biometric_updates']
          .sum()
              .sort_values(ascending=False)
                  .head(10)
                  )

plt.figure(figsize=(10,5))
state_bio.plot(kind='bar')
plt.title("Top 10 States by Aadhaar Biometric Updates")
plt.xlabel("State")
plt.ylabel("Total Biometric Updates")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['total_biometric_updates'], bins=30)
plt.title("Distribution of Aadhaar Biometric Updates")
plt.xlabel("Total Biometric Updates")
plt.ylabel("Frequency")
plt.show()

# %%
threshold = df['total_biometric_updates'].quantile(0.99)
anomalies = df[df['total_biometric_updates'] > threshold]
anomalies.head()
# Out:
#           date              state      district   pincode  bio_age_5_17  \
# 0   01-03-2025            Haryana  Mahendragarh  123029.0         280.0
# 2   01-03-2025  Jammu and Kashmir         Punch  185101.0         643.0
# 3   01-03-2025              Bihar       Bhojpur  802158.0         256.0
# 4   01-03-2025         Tamil Nadu       Madurai  625514.0         271.0
# 15  01-03-2025              Bihar      Vaishali  844504.0         426.0
#
#     bio_age_17_  total_biometric_updates
# 0         577.0                    857.0
# 2        1091.0                   1734.0
# 3         980.0                   1236.0
# 4         815.0                   1086.0
# 15        958.0                   1384.0

# %%
# df['BUII'] = df['total_biometric_updates'] / df['total_enrolments']

# %%
print(df.columns)
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_',
#        'total_biometric_updates'],
#       dtype='object')

# %%
state_bio = df.groupby('state')['total_biometric_updates'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
state_bio.head(10).plot(kind='bar')
plt.title("Top 10 States by Biometric Updates")
plt.xlabel("State")
plt.ylabel("Total Biometric Updates")
plt.show()

# %%
import matplotlib.pyplot as plt
df['total_biometric_updates'] = df['bio_age_5_17'] + df['bio_age_17_']
plt.figure(figsize=(8,5))
plt.hist(df['total_biometric_updates'], bins=30)
plt.title("Distribution of Biometric Updates")
plt.xlabel("Total Biometric Updates")
plt.ylabel("Frequency")
plt.show()

# %%
df.describe()
# Out:
#             pincode  bio_age_5_17   bio_age_17_  total_biometric_updates
# count  1.524217e+06  1.524217e+06  1.524217e+06             1.524217e+06
# mean   5.218406e+05  2.066260e+01  2.171282e+01             4.237542e+01
# std    1.986266e+05  9.201759e+01  9.693803e+01             1.785537e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00             0.000000e+00
# 25%    3.911600e+05  1.000000e+00  1.000000e+00             3.000000e+00
# 50%    5.223150e+05  4.000000e+00  4.000000e+00             8.000000e+00
# 75%    6.885380e+05  1.100000e+01  1.100000e+01             2.300000e+01
# max    8.554560e+05  8.002000e+03  7.625000e+03             1.338100e+04

# %%
df = df.fillna(0)

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1524217 entries, 0 to 1524216
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   date                     1524217 non-null  object
#  1   state                    1524217 non-null  object
#  2   district                 1524217 non-null  object
#  3   pincode                  1524217 non-null  float64
#  4   bio_age_5_17             1524217 non-null  float64
#  5   bio_age_17_              1524217 non-null  float64
#  6   total_biometric_updates  1524217 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 81.4+ MB
# date                       0
# state                      0
# district                   0
# pincode                    0
# bio_age_5_17               0
# bio_age_17_                0
# total_biometric_updates    0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("api_data_aadhar_biometric.csv")
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815
